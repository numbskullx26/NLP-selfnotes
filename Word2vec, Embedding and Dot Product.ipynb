# %%
from IPython.display import Image
Image(filename="C:\\Users\\Indrajeet Sarkar\\Pictures\\Screenshots\\Screenshot 2023-02-20 230206.png")

# %% [markdown]
# ##   Count Vectorizer

# %% [raw]
# the package sklearn.feature_extraction.text has a class called CountVectorizer.
# Converts text to a bag of words.
# Converts it into a matrix format of words into numbers.(A form of Encoding)

# %%
from sklearn.feature_extraction.text import CountVectorizer
corpus = ['hello brother','just plain boring life','help me finish this please']
vectorizer = CountVectorizer()
vectorizer.fit(corpus)
X = vectorizer.transform(corpus)

# %%
print(X)
# Out:
#   (0, 1)	1
#   (0, 3)	1
#   (1, 0)	1
#   (1, 5)	1
#   (1, 6)	1
#   (1, 8)	1
#   (2, 2)	1
#   (2, 4)	1
#   (2, 7)	1
#   (2, 9)	1
#   (2, 10)	1

# %% [markdown]
# ## TfidfVectorizer

# %% [raw]
# the package sklearn.feature_extraction.text has a class called TfidfVectorizer.
# Converts text to a bag of words with tf-idf weighting.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
corpus = ['hello brother','just plain boring life','help me finish this please']
vectorizer = TfidfVectorizer()
vectorizer.fit(corpus)
Y = vectorizer.transform(corpus)

# %%
print(Y)
# Out:
#   (0, 3)	0.7071067811865476
#   (0, 1)	0.7071067811865476
#   (1, 8)	0.5
#   (1, 6)	0.5
#   (1, 5)	0.5
#   (1, 0)	0.5
#   (2, 10)	0.4472135954999579
#   (2, 9)	0.4472135954999579
#   (2, 7)	0.4472135954999579
#   (2, 4)	0.4472135954999579
#   (2, 2)	0.4472135954999579
